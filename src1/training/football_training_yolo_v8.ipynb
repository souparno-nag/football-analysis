# %%
# !pip install ultralytics
# !pip install roboflow

# %% [markdown]
# # Get Dataset

# %%
import os
from dotenv import load_dotenv
load_dotenv()
roboflow_api_key = os.getenv("YOLOV8_ROBOFLOW_API_KEY")

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key=roboflow_api_key)
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to football-players-detection-1 in yolov8:: 100%|██████████| 1338/1338 [00:00<00:00, 6354.24it/s]

# %%
dataset.location
# Out:
# '/home/souparno/Projects/football-analysis/src1/training/football-players-detection-1'

# %% [markdown]
# # Transfer the train and test files

# %%
import shutil

shutil.move("football-players-detection-1/train",
            "football-players-detection-1/football-players-detection-1/train"
            )

shutil.move("football-players-detection-1/test",
            "football-players-detection-1/football-players-detection-1/test"
            )

shutil.move("football-players-detection-1/valid",
            "football-players-detection-1/football-players-detection-1/valid"
            )
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
dataset_location = './football-players-detection-1'

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset_location}/data.yaml epochs=100 imgsz=640
# Out:
# New https://pypi.org/project/ultralytics/8.4.18 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.4.14 🚀 Python-3.10.12 torch-2.10.0+cu128 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3778MiB)
# ...

# %% [markdown]
# ### Move to current directory

# %%
# %cp /home/souparno/Projects/football-nts-detection/runs/detect/train5/weights/best.pt ../models/
# %cp /home/souparno/Projects/football-nts-detection/runs/detect/train5/weights/last.pt ../models/
